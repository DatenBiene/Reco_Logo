# %% [markdown]
# https://docs.opencv.org/3.0-beta/doc/py_tutorials/py_tutorials.html

# %% [markdown]
# # A quick Image Manipulation Cheat Sheet

# %% [markdown]
# Here we import the library we need

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %% [markdown]
# Let's display our first image

# %% [markdown]
# We creat a cv2 object

# %%
img = cv2.imread('Fatou.png',1)

# %%
plt.imshow(img)
plt.xticks([]), plt.yticks([])# to hide tick values on X and Y axis
plt.title('Pierre Fatou 1878-1929')
plt.show()

# %% [markdown]
# Let's manipulate the image we are going to use in this project

# %%
tinder= cv2.imread('/Users/Delanoue/Documents/GitHubRepo/Reco_Logo/Logo_app/Tinder.jpg')

# %%
tinder.shape
# Out:
# (380, 380, 3)

# %% [markdown]
# Let's take a look at it :

# %%
plt.imshow(tinder)

# %% [markdown]
# The colours are not correct. We need to perform a conversion :

# %%
tinder = cv2.cvtColor(tinder, cv2.COLOR_BGR2RGB) #because cv2 use BGR and plt use RGB

# %%
plt.imshow(tinder)

# %% [markdown]
# Remember :
#
# RGB --- value (0-255)Red, (0-255)Green, (0-255)Blue
# RGB stands for Red Green Blue. Most often, an RGB color is stored in a structure or unsigned integer with Blue occupying the least significant "area" (a byte in 32-bit and 24-bit formats), Green the second least, and Red the third least.
#
# BGR is the same, except the order of areas is reversed. Red occupies the least significant area, Green the second (still), and Blue the third.
#
# Example: #FF0000 is pure red when read as an RGB hex color (#rrggbb), because the third area (numbers are read right to left!) is FF (maximum value, full color) and the other two areas are 00 (minimum value, no color). If #FF0000 were read as a BGR hex color, it'd be pure blue.
#
# (Source : https://stackoverflow.com/questions/367449/bgr-color-space )

# %% [markdown]
# We can modify pixels

# %%
tinder[100,:]=np.array([0,66,0])

# %%
plt.imshow(tinder)

# %%
tinder[:,100]=np.array([0,66,0])
plt.imshow(tinder)

# %%
foot = cv2.imread('mbappe.jpg')
foot = cv2.cvtColor(foot, cv2.COLOR_BGR2RGB)
foot.shape
# Out:
# (380, 675, 3)

# %%
plt.imshow(foot)
plt.xticks([]), plt.yticks([]) # to hide tick values on X and Y axis
plt.show()

# %%
mbappe = foot[:, 130:450]
plt.imshow(mbappe)

# %% [markdown]
# Rotation for data augmentation

# %%
img = cv2.imread('/Users/Delanoue/Documents/GitHubRepo/Reco_Logo/Logo_app/Tinder.jpg',0)
num_rows, num_cols = img.shape[:2]

rotation_matrix = cv2.getRotationMatrix2D((num_cols/2, num_rows/2), 30, 1)
img_rotation = cv2.warpAffine(img, rotation_matrix, (num_cols, num_rows))
plt.imshow(img_rotation)

# %%
img = cv2.imread('/Users/Delanoue/Documents/GitHubRepo/Reco_Logo/Paint_image/logo_drew/tinder_10.png',0)
img=255-img
plt.imshow(img,cmap='binary')

# %% [markdown]
# 90 degres rotation

# %%
num_rows, num_cols = img.shape[:2]
rotation_matrix = cv2.getRotationMatrix2D((num_cols/2, num_rows/2), 0, 1)
img_rotation = cv2.warpAffine(img, rotation_matrix, (num_cols, num_rows))
plt.imshow(img_rotation,cmap='binary')
